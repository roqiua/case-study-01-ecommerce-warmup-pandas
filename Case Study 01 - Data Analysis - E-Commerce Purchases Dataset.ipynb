# %%
import pandas as pd

# %%
data = pd.read_csv('Ecommerce Purchases')
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data["Lot"].str.split(" ").str[1].unique()
# Out:
# array(['in', 'rn', 'vE', ..., 'HW', 'UD', 'rU'],
#       shape=(2649,), dtype=object)

# %%
data["Lot"].head(10)
# Out:
# 0    46 in
# 1    28 rn
# 2    94 vE
# 3    36 vm
# 4    20 IE
# 5    21 XT
# 6    96 Xt
# 7    96 pG
# 8    45 JN
# 9    15 Ug
# Name: Lot, dtype: object

# %% [markdown]
# ### 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# ### 3. Check Datatype of Each Column

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# ### 4. Check null values in the dataset

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# ### 5. How many rows and columns are there in our Dataset?

# %%
data.shape #(row , col)
# Out:
# (10000, 14)

# %%
len(data)
# Out:
# 10000

# %%
len(data.columns)
# Out:
# 14

# %% [markdown]
# ### 6. Highest and Lowest Purchase Prices.

# %%
data[data["Purchase Price"] == data["Purchase Price"].max()]
# Out:
#                                         Address    Lot AM or PM  \
# 2092  63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807      PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
#
#                                            Browser Info  \
# 2092  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 7807  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_4)...
#
#                         Company     Credit Card CC Exp Date  CC Security Code  \
# 2092                Pitts Group   4292741269160       06/18               824
# 7807  Porter, Johnson and Pratt  30109394842259       11/25               918
#
#         CC Provider                     Email                     Job  \
# 2092        Maestro  heatherwoodard@lloyd.com  Surveyor, hydrographic
# 7807  VISA 16 digit         kelli72@gmail.com     Surveyor, insurance
#
#            IP Address Language  Purchase Price
# 2092  172.197.216.229       el           99.99
# 7807     89.51.92.242       de           99.99

# %%
pd.DataFrame (data.loc[data["Purchase Price"].idxmax()])
# Out:
#                                                                2092
# Address                   63773 Shelton Greens\nAshleyton, MA 00493
# Lot                                                           56 lu
# AM or PM                                                         AM
# Browser Info      Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# Company                                                 Pitts Group
# Credit Card                                           4292741269160
# CC Exp Date                                                   06/18
# CC Security Code                                                824
# CC Provider                                                 Maestro
# Email                                      heatherwoodard@lloyd.com
# Job                                          Surveyor, hydrographic
# IP Address                                          172.197.216.229
# Language                                                         el
# ...

# %%
data.loc[data["Purchase Price"].idxmax() , ["Email" , "Address"]]
# Out:
# Email                       heatherwoodard@lloyd.com
# Address    63773 Shelton Greens\nAshleyton, MA 00493
# Name: 2092, dtype: object

# %%
data[["Email" , "Address"]][data["Purchase Price"] == data["Purchase Price"].max()]
# Out:
#                          Email                                    Address
# 2092  heatherwoodard@lloyd.com  63773 Shelton Greens\nAshleyton, MA 00493
# 7807         kelli72@gmail.com      PSC 6177, Box 1004\nAPO AA 57143-1269

# %%
data["Purchase Price"].min()
# Out:
# np.float64(0.0)

# %%
data[data["Purchase Price"] == data["Purchase Price"].min()]
# Out:
#                                                 Address    Lot AM or PM  \
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
#
#                                            Browser Info  \
# 2876  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_9...
# 5487  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 2876  Lyons, Diaz and Clark  4204500444841766       01/18                38
# 5487         Flynn and Sons    30469912089738       09/23               236
#
#         CC Provider                 Email                   Job  \
# 2876  VISA 16 digit  jennifer11@baker.com  Biomedical scientist
# 5487       Discover   mjohnson@austin.org         Stage manager
#
#           IP Address Language  Purchase Price
# 2876  223.47.177.174       it             0.0
# 5487     43.99.56.59       zh             0.0

# %% [markdown]
# ### 7. Average Purchase Price

# %%
data['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %% [markdown]
# ### 8. How many people have French 'fr' as their Language?

# %%
data["Language"]
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
data.groupby("Language")["Language"].count()["fr"]
# Out:
# np.int64(1097)

# %%
data[data["Language"] == "fr"].value_counts("Language")
# Out:
# Language
# fr    1097
# Name: count, dtype: int64

# %%
(data["Language"] == "fr").sum()
# Out:
# np.int64(1097)

# %%
len(data[data["Language"] == "fr"])
# Out:
# 1097

# %%
data.groupby("Language").size()
# Out:
# Language
# de    1155
# el    1137
# en    1098
# es    1095
# fr    1097
# it    1086
# pt    1118
# ru    1155
# zh    1059
# dtype: int64

# %% [markdown]
# ### 9. Job Title Contains Engineer

# %%
data["Job"]
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
data["Job"].nunique()
# Out:
# 623

# %%
data["Job"].str.contains("Engineer", na=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
data[data["Job"].str.contains("Engineer", na=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# 64    937 Weaver Isle Apt. 096\nTracyborough, KY 182...  97 QO       AM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# 92                Unit 9659 Box 0618\nDPO AA 00377-5360  37 jN       AM
# ...                                                 ...    ...      ...
# 9868                   Unit 9129 Box 2546\nDPO AP 96513  78 Ei       AM
# 9922  0850 Joseph Estate Apt. 649\nNew Brookefort, K...  82 SJ       AM
# 9925  09281 Mills Court Apt. 022\nWatkinstown, WI 83...  15 PM       PM
# 9945    693 Gomez Keys\nWest Marcushaven, SC 32366-3890  60 tG       PM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
#
#                                            Browser Info  \
# ...

# %%
len(data[data["Job"].str.contains("Engineer", na=False,case=False)])
# Out:
# 984

# %% [markdown]
# ### 10. Find The Email of the person with the following IP Address: 132.207.160.22

# %%
data["Email"][data["IP Address"] == '132.207.160.22']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# ### 11. How many People have Mastercard as their Credit Card Provider and made a purchase above 50?

# %%
((data["CC Provider"] == 'Mastercard') & (data["Purchase Price"] > 50)).sum()
# Out:
# np.int64(405)

# %% [markdown]
# ### 12. Find the email of the person with the following Credit Card Number: 4664825258997302

# %%
data["Email"][data["Credit Card"] == 4664825258997302]
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
data[data["Credit Card"] == '4664825258997302']
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price]
# Index: []

# %% [markdown]
# ### 13. How many people purchase during the AM and how many people purchase during PM?

# %%
(data["AM or PM"] == "AM").sum()
# Out:
# np.int64(4932)

# %%
(data["AM or PM"] == "PM").sum()
# Out:
# np.int64(5068)

# %% [markdown]
# ### 14. How many people have a credit card that expires in 2020?

# %%
data["CC Exp Date"]
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
(data["CC Exp Date"].str.split('/').str[1] == "20").sum()
# Out:
# np.int64(988)

# %%
(data["CC Exp Date"].str[-2:] == "20").sum()
# Out:
# np.int64(988)

# %%
data["CC Exp Date"].str.endswith("20").sum()
# Out:
# np.int64(988)

# %% [markdown]
# ### 15. What are the top 5 most popular email providers (e.g. gmail.com, yahoo.com, etc...)

# %%
data["Email"].str.split('@').str[1].value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
